# %% [markdown]
# ## Sound
#    - Produced by vibration of objects
#    - Vibrations determnine oscillation of air molecules
#    - Alteration of air pressure causes a wave

# %%
import matplotlib.pyplot as plt
plt.imshow(plt.imread('waveform.webp'))

# %% [markdown]
# ### Frequency and Amplitude:
#    - Higher frequency => Higher Pitch
#    - Higher Amplitude => Louder sound

# %%
plt.imshow(plt.imread('freq_amp.png'))

# %% [markdown]
# ### Analog to Digital Conversion
# Analog to Digital Conversion (ADC) is the process of converting an analog signal into a digital signal.
# -  Signal sampled at uniform time intervals (Sample rate - amount of samples taken in a second).
# -  Amplitude quantised with limited number of bits (Bit depth).

# %% [markdown]
# ### Fourier Transform
# -  Decompose complex periodic sounds into sum of sine waves oscillating at different frequencies

# %%
plt.imshow(plt.imread('fourier.png'))

# %%
plt.imshow(plt.imread('fourier_2.png'))
# From time domain to frequency domain

# %% [markdown]
# ### Short Time Fourier Transform
#
# -  Compute different FFT at different time intervals
# -  Preserves time information
# -  Fixed frame size (eg - 2048 samples)
# -  Gives a spectrogram (time + frequency + magnitude)

# %% [markdown]
# ### Mel Frequency Cepstral Coefficients
# -  Captures textural aspects of sound
# -  Frequency domain feature
# -  Approximate human auditory system
# -  Calculated at each frame

# %% [markdown]
# ### DL preprocessing pipeline for audio data

# %%
plt.imshow(plt.imread('pipeline.png'))
